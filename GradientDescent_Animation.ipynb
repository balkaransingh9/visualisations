# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
def f(x, y):
    #return (np.sin(x)*y + np.sin(y)*x)
    return (x**2)+(y**2)
def df(x,y):
  return 2x+2y

x = np.linspace(-6, 6, 60)
y = np.linspace(-6, 6, 60)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')
ax.plot_surface(X, Y, Z, cmap='viridis')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(40, 25)
plt.rcParams["figure.figsize"] = (15,10)

# %%
plt.contour(X, Y, Z,color='black')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: The following kwargs were not used by contour: 'color'
#   """Entry point for launching an IPython kernel.

# %%
import torch
import numpy as np
#This is gradient calculation... need to do this at each point
#https://medium.com/@zhang_yang/gradient-calculation-examples-in-pytorch-bffe287d8634 useful..
#https://colah.github.io/posts/2015-08-Backprop/
#https://youtu.be/6U2rTOhS3fA
#x = torch.tensor([[[1.0,1.0],[7.0,7.0]],[[1.0,1.0],[7.0,7.0]],[[1.0,1.0],[7.0,7.0]],[[1.0,1.0],[7.0,7.0]]], requires_grad = True) #can construct a tensor of all xy pairs like this...
x = torch.tensor([[1.0],[7.0]], requires_grad = True) #can construct a tensor of all xy pairs like this...
y = torch.sum(x[0]**2 + x[1]**2)
y.backward()
x.grad.detach()
# Out:
# array([[ 2.],
#        [14.]], dtype=float32)

# %%
# make it flexible so it takes in any number of variables..
import torch

init = [[2.0],[3.5]]
lr = 0.1
iterations = 0
iterates = list()

while iterations < 20:
  x = torch.tensor(init, requires_grad=True)
  y = torch.sum(x[0]**2 + 4*x[1]**2 - 4*x[1])
  y.backward()
  gradient = x.grad.detach()
  ans = []
  for i in range(0,gradient.shape[0]):
    x = init[i][0]-lr*gradient[i][0]
    ans.append([x])
  init = ans
  print(ans)
  iterations += 1
# Out:
# [[tensor(1.6000)], [tensor(1.1000)]]
# [[tensor(1.2800)], [tensor(0.6200)]]
# [[tensor(1.0240)], [tensor(0.5240)]]
# [[tensor(0.8192)], [tensor(0.5048)]]
# [[tensor(0.6554)], [tensor(0.5010)]]
# [[tensor(0.5243)], [tensor(0.5002)]]
# [[tensor(0.4194)], [tensor(0.5000)]]
# [[tensor(0.3355)], [tensor(0.5000)]]
# [[tensor(0.2684)], [tensor(0.5000)]]
# [[tensor(0.2147)], [tensor(0.5000)]]
# [[tensor(0.1718)], [tensor(0.5000)]]
# [[tensor(0.1374)], [tensor(0.5000)]]
# [[tensor(0.1100)], [tensor(0.5000)]]
# [[tensor(0.0880)], [tensor(0.5000)]]
# [[tensor(0.0704)], [tensor(0.5000)]]
# [[tensor(0.0563)], [tensor(0.5000)]]
# [[tensor(0.0450)], [tensor(0.5000)]]
# [[tensor(0.0360)], [tensor(0.5000)]]
# [[tensor(0.0288)], [tensor(0.5000)]]
# [[tensor(0.0231)], [tensor(0.5000)]]

# %%
gradient.shape
# Out:
# torch.Size([2, 1])
